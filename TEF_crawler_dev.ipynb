# %%
import datetime
import sys
import time
import typing
import re
import os

import pandas as pd
import requests
from loguru import logger
from pydantic import BaseModel
from bs4 import BeautifulSoup
import configparser

# %%
def futures_header():
    """網頁瀏覽時, 所帶的 request header 參數, 模仿瀏覽器發送 request"""
    return {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        "Cache-Control": "no-cache",
        "Connection": "keep-alive",
        "Content-Length": "101",
        "Content-Type": "application/x-www-form-urlencoded",
        "Host": "www.taifex.com.tw",
        "Origin": "https://www.taifex.com.tw",
        "Pragma": "no-cache",
        "Referer": "https://www.taifex.com.tw/cht/3/dlFutDailyMarketView",
        "Sec-Fetch-Dest": "document",
        "Sec-Fetch-Mode": "navigate",
        "Sec-Fetch-Site": "same-origin",
        "Sec-Fetch-User": "?1",
        "Upgrade-Insecure-Requests": "1",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.113 Safari/537.36",
    }

# %%
def crawler_futures(
    date: str,
) -> pd.DataFrame:
    """期交所爬蟲"""
    url = "https://www.taifex.com.tw/cht/3/futDataDown"
    form_data = {
        "queryType": "1",
        "goDay": "",
        "doQuery": "1",
        "dateaddcnt": "",
        "queryDate": date.replace("-", "/"),
        "commodityId": prod,
    }
    # 避免被期交所 ban ip, 在每次爬蟲時, 先 sleep 5 秒
    time.sleep(5)
    resp = requests.post(
        url,
        headers=futures_header(),
        data=form_data,
    )
    if resp.ok:
        if resp.content:
            df = pd.read_csv(
                io.StringIO(
                    resp.content.decode(
                        "big5"
                    )
                ),
                index_col=False,
            )
    else:
        return pd.DataFrame()
    return df

# %%
url = "https://www.taifex.com.tw/cht/3/futDailyMarketReport"

# %%
date = '2023-01-17'
prod = 'MTX'

# %%
    form_data = {
        "queryType": "2",
        "marketCode": "0",
        "dateaddcnt": "",
        "commodity_id": prod,
        "commodity_id2": "",
        "queryDate": date.replace("-", "/"),
        "MarketCode": "0",
        "commodity_idt": prod,
        "commodity_id2t": "",
        "commodity_id2t2": "",
    }

# %%
form_data
# Out:
# {'queryType': '2',
#  'marketCode': '0',
#  'dateaddcnt': '',
#  'commodity_id': 'MTX',
#  'commodity_id2': '',
#  'queryDate': '2023/01/17',
#  'MarketCode': '0',
#  'commodity_idt': 'MTX',
#  'commodity_id2t': '',
#  'commodity_id2t2': ''}

# %%
    time.sleep(5)

# %%
    resp = requests.post(
        url,
        headers=futures_header(),
        data=form_data,
    )

# %%
resp
# Out:
# <Response [200]>

# %%
resp.ok
# Out:
# True

# %%
resp.content
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">\r\n\r\n\r\n<head><meta http-equiv="X-UA-Compatible" content="IE=edge"></head>\r\n<html xmlns="http://www.w3.org/1999/xhtml" lang="zh-TW" >\r\n\t\t<head>\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n  <link rel="shortcut icon" type="image/x-icon" href="/cht/resources/front/cht/images/favicon.ico" />\r\n  <meta property="og:image" content="https://www.taifex.com.tw/chinese/images/fb_logo.jpg" />\r\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n  <title>\xe8\x87\xba\xe7\x81\xa3\xe6\x9c\x9f\xe8\xb2\xa8\xe4\xba\xa4\xe6\x98\x93\xe6\x89\x80-\xe4\xba\xa4\xe6\x98\x93\xe8\xb3\x87\xe8\xa8\x8a-\xe5\xa4\xa7\xe9\xa1\x8d\xe4\xba\xa4\xe6\x98\x93\xe4\xba\xba\xe6\x9c\xaa\xe6\xb2\x96\xe9\x8a\xb7\xe9\x83\xa8\xe4\xbd\x8d\xe7\xb5\x90\xe6\xa7\x8b-\xe6\x9f\xa5\xe8\xa9\xa2-\xe6\x9c\x9f\xe8\xb2\xa8\xe5\
# ...

# %%
Soup = BeautifulSoup(resp.content,'html.parser')

# %%
Soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <head><meta content="IE=edge" http-equiv="X-UA-Compatible"/></head>
# <html lang="zh-TW" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/cht/resources/front/cht/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="https://www.taifex.com.tw/chinese/images/fb_logo.jpg" property="og:image">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>臺灣期貨交易所-交易資訊-三大法人-查詢-區分各期貨契約-依日期</title>
# <link href="/cht/resources/front/cht/css/global.css" rel="stylesheet" type="text/css"/>
# <link href="/cht/resources/front/cht/css/content.css" rel="stylesheet" type="text/css"/>
# <link href="/cht/resources/front/cht/css/index.css" rel="stylesheet" type="text/css"/>
# ...

# %%
 Soup.find(class_='table_f')
# Out:
# <table bgcolor="#336699" border="0" bordercolordark="#ffffff" cellpadding="0" cellspacing="0" class="table_f" width="920px"> <tbody>
# <tr class="12bk">
# <td align="middle" bgcolor="#6699CC" colspan="3" rowspan="2" scope="colgroup"></td>
# <th align="middle" bgcolor="#6699CC" colspan="6" scope="colgroup">交易口數與契約金額</th>
# <th align="middle" bgcolor="#6699CC" colspan="6" scope="colgroup">未平倉餘額</th>
# </tr>
# <tr class="12bk">
# <th align="right" bgcolor="#6699CC" colspan="2" scope="colgroup">多方</th>
# <th align="right" bgcolor="#6699CC" colspan="2" scope="colgroup">空方</th>
# <th align="right" bgcolor="#6699CC" colspan="2" scope="colgroup">多空淨額</th>
# <th align="right" bgcolor="#6699CC" colspan="2" scope="colgroup">多方</th>
# <th align="right" bgcolor="#6699CC" colspan="2" scope="colgroup">空方</th>
# <th align="right" bgcolor="#6699CC" colspan="2" scope="colgroup">多空淨額</th>
# </tr>
# <tr class="12bk">
# <th bgcolor="#6699CC" scope="col" width="15"><div align="center">序<br/>號</div></th>
# ...

# %%
table_f = Soup.find(class_='table_f')

# %%
table_f
# Out:
# <table border="0" cellpadding="2" cellspacing="1" class="table_f" width="965">
# <tbody>
# <tr bgcolor="#6699CC" class="12whit">
# <th width="30">契約</th>
# <th width="50">到期<br/>月份<br/>(週別)</th>
# <th width="50">開盤價</th>
# <th width="50">最高價</th>
# <th width="50">最低價</th>
# <th width="50">最後<br/>成交價</th>
# <th width="65">漲跌價</th>
# <th width="70">漲跌%</th>
# <th width="50">*盤後交易時段成交量</th>
# <th width="50">*一般交易時段成交量</th>
# <th width="50">*合計成交量</th>
# <th width="50">結算價</th>
# <th width="60">*未沖銷契約量</th>
# <th width="50">最後最佳買價</th>
# <th width="50">最後最佳賣價</th>
# <th width="50">歷史最高價</th>
# <th width="50">歷史最低價</th>
# </tr>
# <tr bgcolor="ivory">
# <td class="12bk">
# <div align="center">MTX    </div>
# </td>
# <td class="12bk"><div align="center">202301  </div></td>
# <td align="right" class="12bk">14922</td>
# <td align="right" class="12bk">14970</td>
# <td align="right" class="12bk">14905</td>
# <td align="right" class="12bk">14928</td>
# <td align="middle" class="12green">
# ...

# %%
type(table_f)
# Out:
# NoneType

# %%
Soup.find(class_='table_f') == None
# Out:
# False

# %%
table_f("tr")[-1]("td")[12].text
# Out:
# '53258'

# %%
re.sub(r"\r|\n|\t|,| ", "", table_f("tr")[-1]("td")[-4].text)
# Out:
# '9387'

# %%
table_f("tr")[5]('td')[-2].text
# Out:
# '\r\n\t\t\t\t\t\t\t\t    \r\n\t\t\t\t\t\t\t\t    9,347\n'

# %%
            all_contracts = table_f("tr")[-1]
            buyer_a_01_01 = all_contracts.find(headers ='buyer_a_01_01').text
            buyer_a_01_01_index_1 = buyer_a_01_01.index('(')
            buyer_a_01_01_index_2 = buyer_a_01_01.index(')')
            buyer_a_01_01_count = int(buyer_a_01_01[(buyer_a_01_01_index_1+1):buyer_a_01_01_index_2].replace(",", ""))

            seller_a_01_01 = all_contracts.find(headers ='seller_a_01_01').text
            seller_a_01_01_index_1 = seller_a_01_01.index('(')
            seller_a_01_01_index_2 = seller_a_01_01.index(')')
            seller_a_01_01_count = int(seller_a_01_01[(seller_a_01_01_index_1+1):seller_a_01_01_index_2].replace(",", ""))

# %%
buyer_a_01_01_count
# Out:
# 33710

# %%
 seller_a_01_01_count
# Out:
# 24315

# %%
table_f("tr")[-1]
# Out:
# <tr>
# <td align="center" bgcolor="ivory" class="11b" headers="expiry_a">
# 											所有<br/>契約</td>
# <td bgcolor="ivory" class="11b" headers="buyer_a buyer_a_01 buyer_a_01_01"> <div align="center">
# 											33,710<br/>
#                                       				(33,710)
# 												</div></td>
# <td bgcolor="ivory" class="11b" headers="buyer_a buyer_a_01 buyer_a_01_02"> <div align="center">
# 											36.3%<br/>
# 													(36.3%)
# 												</div></td>
# <td bgcolor="ivory" class="11b" headers="buyer_a buyer_a_02 buyer_a_02_01"> <div align="center">
# 											43,240<br/>
# 													(41,187)
# 												</div></td>
# <td bgcolor="ivory" class="11b" headers="buyer_a buyer_a_02 buyer_a_02_02"> <div align="center">
# 											46.5%<br/>
# 													(44.3%)
# 												</div></td>
# <td bgcolor="ivory" class="11b" headers="seller_a seller_a_01 seller_a_01_01"> <div align="center">
# 											31,044<br/>
# 													(24,315)
# ...

# %%
a = table_f("tr")[-1].find(headers ='buyer_a_01_01').text

# %%
a_index_1 = a.index('(')

# %%
a_index_2 = a.index(')')

# %%
b = a[(a_index_1+1):a_index_2]

# %%
int(b.replace(",", ""))
# Out:
# 33710

# %%
b.replace(",", "")
# Out:
# '33710'

# %%
table_f("tr")[3]
# Out:
# <tr>
# <td bgcolor="ivory" class="12bk" headers="name_a" rowspan="3">
# <div align="center">臺股期貨(TX+MTX/4)</div></td>
# <td align="center" bgcolor="ivory" class="11b" headers="expiry_a">
#
# 													週契約
# 												</td>
# <td bgcolor="ivory" class="11b" headers="buyer_a buyer_a_01 buyer_a_01_01"> <div align="center">
# 											72<br/>
#                                       				(10)
# 												</div></td>
# <td bgcolor="ivory" class="11b" headers="buyer_a buyer_a_01 buyer_a_01_02"> <div align="center">
# 											51.8%<br/>
# 													(7.2%)
# 												</div></td>
# <td bgcolor="ivory" class="11b" headers="buyer_a buyer_a_02 buyer_a_02_01"> <div align="center">
# 											103<br/>
# 													(10)
# 												</div></td>
# <td bgcolor="ivory" class="11b" headers="buyer_a buyer_a_02 buyer_a_02_02"> <div align="center">
# 											74.1%<br/>
# 													(7.2%)
# 												</div></td>
# ...

# %%
df
# Out:
#             交易日期   契約           到期月份(週別)     開盤價     最高價     最低價     收盤價  \
# 0     2022/12/30  ZFF           202301    1488.8    1502  1488.2    1494
# 1     2022/12/30  ZFF           202302    1489.2    1500    1489  1490.6
# 2     2022/12/30  ZFF           202303    1496.8  1496.8    1488    1488
# 3     2022/12/30  ZFF           202306         -       -       -       -
# 4     2022/12/30  ZFF           202309         -       -       -       -
# ...          ...  ...                ...     ...     ...     ...     ...
# 1728  2022/12/30  QFF  202303/202309           -       -       -       -
# 1729  2022/12/30  CDF  202306/202309       -1.28   -1.23   -1.28   -1.23
# 1730  2022/12/30  DDF  202306/202309           -       -       -       -
# 1731  2022/12/30  DFF  202306/202309           -       -       -       -
# 1732  2022/12/30  QFF  202306/202309           -       -       -       -
#
#        漲跌價    漲跌%  成交量     結算價 未沖銷契約數  最後最佳買價  最後最佳賣價   歷史最高價   歷史最低價  \
# ...

# %%
class TaiwanFuturesDaily(BaseModel):
    date: str
    FuturesID: str
    ContractDate: str
    Open: float
    Max: float
    Min: float
    Close: float
    Change: float
    ChangePer: float
    Volume: float
    SettlementPrice: float
    OpenInterest: int
    TradingSession: str

# %%
def check_schema(
    df: pd.DataFrame,
) -> pd.DataFrame:
    """檢查資料型態, 確保每次要上傳資料庫前, 型態正確"""
    df_dict = df.to_dict("records")
    df_schema = [
        TaiwanFuturesDaily(
            **dd
        ).__dict__
        for dd in df_dict
    ]
    df = pd.DataFrame(df_schema)
    return df

# %%
def gen_date_list(
    start_date: str, end_date: str
) -> typing.List[str]:
    """建立時間列表, 用於爬取所有資料"""
    start_date = (
        datetime.datetime.strptime(
            start_date, "%Y-%m-%d"
        ).date()
    )
    end_date = (
        datetime.datetime.strptime(
            end_date, "%Y-%m-%d"
        ).date()
    )
    days = (
        end_date - start_date
    ).days + 1
    date_list = [
        str(
            start_date
            + datetime.timedelta(
                days=day
            )
        )
        for day in range(days)
    ]
    return date_list

# %%
start_date = '2022-01-01'
end_date = '2022-01-10'

# %%
    start_date = datetime.datetime.strptime(start_date, "%Y-%m-%d").date()
    end_date = datetime.datetime.strptime(end_date, "%Y-%m-%d").date()
    days = (end_date - start_date).days + 1

# %%
days
# Out:
# 10

# %%
times = pd.date_range(start_date, end_date)

# %%
type(times.strftime('%Y-%m-%d')[1])
# Out:
# str

# %%
times[0]
# Out:
# Timestamp('2022-01-01 00:00:00', freq='D')

# %%
        [str(
            start_date
            + datetime.timedelta(
                days=day
            )
        )
        for day in range(days)]
# Out:
# ['2022-01-01',
#  '2022-01-02',
#  '2022-01-03',
#  '2022-01-04',
#  '2022-01-05',
#  '2022-01-06',
#  '2022-01-07',
#  '2022-01-08',
#  '2022-01-09',
#  '2022-01-10']

# %%
def main(
    start_date: str, end_date: str
):
    date_list = gen_date_list(
        start_date, end_date
    )
    for date in date_list:
        logger.info(date)
        df = crawler_futures(date)
        if len(df) > 0:
            # 欄位中英轉換
            df = colname_zh2en(
                df.copy()
            )
            # 資料清理
            df = clean_data(df.copy())
            # 檢查資料型態
            df = check_schema(df.copy())
            # 這邊先暫時存成 file，下個章節將會上傳資料庫
            df.to_csv(
                f"taiwan_futures_price_{date}.csv",
                index=False,
            )

# %%
            d = {'date': ['2023-01-01'], 
                 'prod': ['TX'],
                 'buyer_top5': [5],
                 'seller_top5':[10]}
            df = pd.DataFrame(data=d)

# %%
df
# Out:
#          date prod  buyer_top5  seller_top5
# 0  2023-01-01   TX           5           10

# %%
datetime.datetime.now().isoformat(sep=" ", timespec="seconds")
# Out:
# '2023-01-27 02:27:36'

# %%
if __name__ == "__main__":
    start_date, end_date = sys.argv[1:]
    main(start_date, end_date)

# %%
env_path = os.path.join(os.path.expanduser('~'), 'env')

def get_db_config():
    config = configparser.ConfigParser()
    config.read(os.path.join(env_path, 'db_config.ini'))
    return config

# %%
db_config = get_db_config()

# %%
db_config['prod']['host']
# Out:
# '34.123.184.207'

# %%
db_config
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[229], line 1
# ----> 1 db_config[0]
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/configparser.py:960, in RawConfigParser.__getitem__(self, key)
#     958 def __getitem__(self, key):
#     959     if key != self.default_section and not self.has_section(key):
# --> 960         raise KeyError(key)
#     961     return self._proxies[key]
#
# KeyError: 0

# %%
financial_db_info= db_config['prod']

# %%
financial_db_info['host']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[243], line 1
# ----> 1 financial_db_info['host']
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/configparser.py:1254, in SectionProxy.__getitem__(self, key)
#    1252 def __getitem__(self, key):
#    1253     if not self._parser.has_option(self._name, key):
# -> 1254         raise KeyError(key)
#    1255     return self._parser.get(self._name, key)
#
# KeyError: 'host'

# %%
os.path.join(env_path, 'db_config.ini')
# Out:
# '/home/ppp1987524/env/db_config.ini'

# %%
            db_config = get_db_config()
            financial_db_info= db_config['prod']
            financial_db_conn_string = "host='" + financial_db_info['host'] + "' user='" + financial_db_info['user'] + "' password='" + financial_db_info['password'] + "' dbname='" + financial_db_info['dbname'] + "'"
            engine = create_engine('postgresql://'+ financial_db_info['user'] +':'+ financial_db_info['password'] +'@'+ financial_db_info['host']':5432/' + financial_db_info['dbname'])
# Out:
#   Cell In[256], line 4
#     engine = create_engine('postgresql://'+ financial_db_info['user'] +':'+ financial_db_info['password'] +'@'+ financial_db_info['host']':5432/' + financial_db_info['dbname'])
#                                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
            db_config = get_db_config()
            financial_db_info= db_config['prod']
            financial_db_conn_string = "host='" + financial_db_info['host'] + "' user='" + financial_db_info['user'] + "' password='" + financial_db_info['password'] + "' dbname='" + financial_db_info['dbname'] + "'"
            engine = create_engine('postgresql://'+ financial_db_info['user'] +':'+ financial_db_info['password'] +'@'+ financial_db_info['host'] + ':5432/' + financial_db_info['dbname'])

# %%
from sqlalchemy import create_engine

# %%
            financial_db_cn= psycopg2.connect(financial_db_conn_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[264], line 1
# ----> 1 financial_db_cn= psycopg2.connect(financial_db_conn_string)
#
# NameError: name 'psycopg2' is not defined

# %%
engine
# Out:
# Engine(postgresql://sqluser:***@34.123.184.207:5432/financialdata_db)

# %%
today = datetime.datetime.now().strftime('%Y-%m-%d')
today
# Out:
# '2023-01-29'

# %%
f'sudo -i -u ppp1987524 -H sh -c \'cd /home/ppp1987524/TFE-data; poetry run python financialdata/crawler/largeTraderFutQry_TX.py {today} {today}; \''
# Out:
# "sudo -i -u ppp1987524 -H sh -c 'cd /home/ppp1987524/TFE-data; poetry run python financialdata/crawler/largeTraderFutQry_TX.py 2023-01-29 2023-01-29; '"
